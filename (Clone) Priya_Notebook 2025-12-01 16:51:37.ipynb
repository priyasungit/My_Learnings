# %% [markdown]
# #Databricks Notebook
#
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)
#
# All my learnings in Databricks will be documented here.
#
# # Markdowns
# ## Formats
# ###Trying the below formats in MD
# * **COLORING** <span style="color:pink">PRIYABHARATHI</span>
# * **ITALICS** *Single Asterix*

# %%
displayHTML("""
<span style="color:pink"><b>PRIYABHARATHI:</b></span>
""")

# %% [markdown]
# ##TASK2##

# %% [markdown]
# Task2: Create a volume namely usage_metrics using sql magic command %sql

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.Usage_metrics;

# %% [markdown]
# Task4: Call the notebook 4_child_nb_dataload using the magic command %run

# %%
# %run "/Users/priyabharathi.sundar@gmail.com/My_Learnings/4_child_nb_dataload"

# %% [markdown]
# Task5: list the file is created in the given volume or not and do the head of this file using fs magic command %fs

# %%
dbutils.fs.ls("/Volumes/workspace/default/Usage_metrics/mobile_os_usage.csv")

print(dbutils.fs.head("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",500))

# %%
df1=display(
  spark.read.csv("/Volumes/workspace/default/Usage_metrics/mobile_os_usage.csv", header=True, inferSchema=True)
)

# %% [markdown]
# Task6: Create a pyspark dataframe df1 reading the data from the above file using pyspark magic command %python

# %%
df1 = spark.read.csv(
    "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",
    header=True,
    inferSchema=True
)

# %% [markdown]
# Task7: Write the above dataframe df1 data into a databricks table called 'default.mobile_os_usage' using pyspark magic command %python

# %%
new_columns = [col.replace(" ", "_").replace("%", "Percent").replace("/", "_") for col in df1.columns]
df1 = df1.toDF(*new_columns)

df1.write.mode("overwrite").saveAsTable("default.mobile_os_usage")

# Verify by showing the first few rows from the table

# %% [markdown]
# Task8: Write sql query to display the data loaded into the table 'default.mobile_os_usage' using the pyspark magic command %python

# %%
display(spark.sql("SELECT * FROM default.mobile_os_usage"))

# %% [markdown]
#  Task 9:Create a python function to convert the given input to upper case

# %%
def get_input_upper(text1):
    return text1.upper()
get_input_upper(input("Enter your name"))

# %% [markdown]
# Task10: Install pandas library using the pip python magic command %pip

# %%
pip install pandas

# %% [markdown]
# Task11: Import pandas, using pandas read_csv and display the output using the magic command %python

# %%
# %python

import pandas as pd

# Read the CSV file into a pandas DataFrame
df_pandas = pd.read_csv("/Volumes/workspace/default/Usage_metrics/mobile_os_usage.csv")

# Display the first few rows
print(df_pandas.head())

# %% [markdown]
# Task12: echo "Magic commands tasks completed" using the linux shell magic command %sh

# %%
# %sh echo "Magic commands tasks completed"
