# %% [markdown]
# 1. Create folder structure using Volume

# %%
#Define Base Paths using python variable
base_path = "/Volumes/workspace/default/usage_metrics"
raw_path = f"{base_path}/raw"
processed_path = f"{base_path}/processed"
archive_path = f"{base_path}/archive"

# %%
dbutils.fs.mkdirs(raw_path)
dbutils.fs.mkdirs(processed_path)
dbutils.fs.mkdirs(archive_path)

# %% [markdown]
# dbutils Usecase – Create Sample Healthcare File
# sample_data = """patient_id,patient_name,age,gender 1,John Doe,68,M 2,Jane Smith,54,F """

# %%
dbutils.fs.put(f"{raw_path}/Healthcare_data.csv", """patient_id,patient_name,age,gender 1,John Doe,68,M 2,Jane Smith,54,F """,
    overwrite = True)

# %% [markdown]
# dbutils Usecase - list the file created
# TODO: List all files available in raw folder using the dbutils command
# dbutils.fs......

# %%
dbutils.fs.ls(raw_path)

# %% [markdown]
# dbutils Usecase – Copy File (raw → processed)

# %%
dbutils.fs.cp(f"{raw_path}/Healthcare_data.csv", f"{processed_path}/Healthcare_data.csv")

# %% [markdown]
# dbutils widget usecase - Create dropdown and text widgets...
# TODO: Create a dropdown widget for environment (dev, qa, prod) using
# TODO: Create a text widget for owner name

# %%
dbutils.widgets.dropdown("Environment", "dev", ["dev", "test", "prod"],"Environment")
dbutils.widgets.text("Owner name", "Priyabharathi Sundar")

# %% [markdown]
#
# dbutils widget Usecase – Read Widget Values environment and owner and print in the screen

# %%
a=dbutils.widgets.get("Environment")
b=dbutils.widgets.get("Owner name")
print(a)
print(b)

# %% [markdown]
# dbutils widget Usecase – Move the above processed File to Archive

# %%
dbutils.fs.mv(f"{processed_path}/Healthcare_data.csv", f"{archive_path}/Healthcare_data.csv")

# %% [markdown]
# dbutils notebook usecase - Run the notebook4 using the dbutils command /Workspace/Users/infoblisstech@gmail.com/databricks-code-repo/databricks_workouts_2025/1_USECASES_NB_FUNDAMENTALS/4_child_nb_dataload

# %%
child_return_value=dbutils.notebook.run("/Workspace/Users/priyabharathi.sundar@gmail.com/My_Learnings/4_child_nb_dataload",60,{"date":"2025-12-08","platform":"Android","some_id":"0"})

# %% [markdown]
# dbutils notebook usecase - exit this notebook TODO: Exit notebook with a success message dbutils.notebook._____("Pipeline completed successfully")

# %%
dbutils.notebook.exit("Pipeline completed successfully")
